# %%
import pandas as pd
import io
import requests
url='https://think.cs.vt.edu/corgis/datasets/csv/cars/cars.csv'
data=pd.read_csv(url)
data.head()
honda = data[data['Identification.Make']=='Honda'] 
honda
gasoline = honda[honda["Fuel Information.Fuel Type"]=="Gasoline"]
gasoline
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 101                 152                240                57
# 102                 152                240                57
# 103                 152                240                57
# 104                 152                240                57
# 105                 152                240                57
# ...                 ...                ...               ...
# 5067                  3                253               201
# 5068                  3                253               201
# 5069                  3                253               201
# 5070                  3                253               201
# 5071                 13                253               201
#
#      Engine Information.Driveline           Engine Information.Engine Type  \
# 101             Front-wheel drive   Honda 3.5L 6 Cylinder 271hp 251 ft-lbs
# 102             Front-wheel drive  Honda 2.4L 4 cylinder 190 hp 162 ft-lbs
# ...

# %%
from sklearn import preprocessing
import numpy as np
testdata = gasoline.set_index(gasoline["Identification.Make"])[["Fuel Information.Highway mpg", "Engine Information.Engine Statistics.Horsepower"]]
testdata.head()
testdata.plot()

# %%
normalized = preprocessing.normalize(testdata)
normalized
# Out:
# array([[0.09186087, 0.99577185],
#        [0.16102864, 0.98694973],
#        [0.16102864, 0.98694973],
#        [0.16102864, 0.98694973],
#        [0.10277392, 0.99470474],
#        [0.16102864, 0.98694973],
#        [0.16102864, 0.98694973],
#        [0.16102864, 0.98694973],
#        [0.16608201, 0.98611194],
#        [0.17112233, 0.98524979],
#        [0.09550243, 0.9954292 ],
#        [0.16608201, 0.98611194],
#        [0.10640357, 0.99432303],
#        [0.17112233, 0.98524979],
#        [0.17112233, 0.98524979],
#        [0.17251532, 0.98500683],
#        [0.17251532, 0.98500683],
#        [0.17251532, 0.98500683],
#        [0.17251532, 0.98500683],
#        [0.16102864, 0.98694973],
#        [0.16102864, 0.98694973],
#        [0.16102864, 0.98694973],
#        [0.16102864, 0.98694973],
#        [0.10640357, 0.99432303],
#        [0.10640357, 0.99432303],
#        [0.18328243, 0.9830603 ],
#        [0.1886416 , 0.982046  ],
#        [0.1886416 , 0.982046  ],
# ...

# %%
testdata.plot(x=0,y=1)

# %%
testdata.plot.scatter(x = 0, y = 1)
